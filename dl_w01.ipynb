# %% [markdown]
# <a href="https://colab.research.google.com/github/KartikayBhardwaj-dev/Deep_learning_college/blob/main/dl_w01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
a = torch.tensor(7)
torch.tensor?

# %%
b = torch.tensor([1.0,2.0,3.0])
print(b.shape)
print(b.ndim)
# Out:
# torch.Size([3])
# 1

# %%
sum = torch.sum(b).item()
mean = torch.mean(b).item()
norm = torch.norm(b).item()
norm
# Out:
# 3.7416574954986572
